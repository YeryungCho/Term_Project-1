# %%
# '비상벨 안전' 크롤링 1달

import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd

titles = []
contents = []

for i in range(1, 610,10):
    link = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B9%84%EC%83%81%EB%B2%A8%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=2&ds=2023.11.03&de=2023.12.03&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start=" + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    url = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']

        # Extract article content using newspaper library
        article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
        article.download()
        article.parse()

        # Append data to lists
        titles.append(title.get_text(strip=True))
        contents.append(article.text)
        
        print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_energency_bell.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 상주시, 남산근린공원 공중화장실 안심비상벨설치
#  - 1페이지 크롤링 완료: 광주 서구 "공중화장실 안심하고 사용하세요"
#  - 1페이지 크롤링 완료: 동대문구 "폭염·한파 걱정없어요" 버스정류장 스마트 쉼터 4곳 설치
#  - 1페이지 크롤링 완료: 성남시의회 김종환 의원 “판교대장지구 버스정류장 내 CCTV‧비상벨설치로 ...
#  - 1페이지 크롤링 완료: 상주 남산근린공원, 공중화장실비상벨설치
#  - 1페이지 크롤링 완료: 혹한에도 따뜻하게… 동대문구 스마트쉼터 운영
#  - 1페이지 크롤링 완료: 동대문구, 청량리역 광장 등 스마트쉼터 4곳 운영
#  - 1페이지 크롤링 완료: 광주 서구, 57개 공중화장실 주민·경찰·공무원 합동점검
#  - 1페이지 크롤링 완료: 이상일, "범죄와 재난 지역에안전시설물 더 확대할 것"
#  - 1페이지 크롤링 완료: [포커스] 이민근 안산시장 "365일 여성안전책임진다"
#  - 2페이지 크롤링 완료: 광주시 서구"공중화장실 안심하고 사용하세요"
#  - 2페이지 크롤링 완료: 이상일 용인시장, '생활안전디자인' 적용 시설물 현장 점검
#  - 2페이지 크롤링 완료: 이상일 용인시장, 범죄예방·생활안전디자인 시설 점검
#  - 2페이지 크롤링 완료: 동대문구 “편의시설 갖춘 스마트쉼터 4곳 1일부터 운영”
#  - 2페이지 크롤링 완료: 안성시, 여성안심특구지정추진협의체 회의 개최…안전시책 추진
#  - 2페이지 크롤링 완료: 종로구, 종로사랑 여성누리단 종합평가보고회 개최
#  - 2페이지 크롤링 완료: 안성시, 여성안심특구지정추진협의체 회의 개최
#  - 2페이지 크롤링 완료: 이상일 용인특례시장, 풍덕천동 ‘생활안전디자인’ 적용 시설물 현장 점검
#  - 2페이지 크롤링 완료: 유니유니, CES 2024서 '안심·안전·만족' 화장실 위한 AIoT 스마트 통합 솔루...
#  - 2페이지 크롤링 완료: "현장에 답" 이상일 용인시장의 잇따른 현장 행보
# ...

# %%
#  '보안등 안전' 크롤링 1달

import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd

# Create empty lists to store data
titles = []
contents = []

for i in range(1, 250,10):
    link = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B3%B4%EC%95%88%EB%93%B1%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=2&ds=2023.11.03&de=2023.12.03&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start='+ str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    url = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']

        # Extract article content using newspaper library
        article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
        article.download()
        article.parse()

        # Append data to lists
        titles.append(title.get_text(strip=True))
        contents.append(article.text)
        
        print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_crawling_emergency_light' index=False)
# Out:
#  - 1페이지 크롤링 완료: ‘광양 감동데이’ 소통행정 나서
#  - 1페이지 크롤링 완료: 강화군, ‘군민의 행복한 일상, 강화의 미래시대 준비’
#  - 1페이지 크롤링 완료: 유천호 인천 강화군수, 2024년 군정 운영 방향 제시
#  - 1페이지 크롤링 완료: 인천시 강화군 등산로 입구에 스마트폴 설치
#  - 1페이지 크롤링 완료: 원주시, '안전한 밤길' 가로등형 블랙박스보안등설치 첫해 성공적 마무리
#  - 1페이지 크롤링 완료: 유천호 강화군수, 2024년 군정 운영방향 시정연설
#  - 1페이지 크롤링 완료: 유천호 강화군수, 2024년 군정 운영방향 시정연설
#  - 1페이지 크롤링 완료: 유천호 강화군수, 2024년 군정 운영방향 시정연설
#  - 1페이지 크롤링 완료: 유천호 강화군수, 2024년 군정 운영 방향 시정연설
#  - 1페이지 크롤링 완료: [울산] 고리원자력본부, '제12회 대한민국 나눔대상 보건복지부장관' 표창 外
#  - 2페이지 크롤링 완료: 유천호 인천 강화군수, 2024년 군정 운영방향 시정연설
#  - 2페이지 크롤링 완료: [포커스] 이민근 안산시장 "365일 여성안전책임진다"
#  - 2페이지 크롤링 완료: 원주시, 올해 가로등형 방범 블랙박스보안등136대 설치
#  - 2페이지 크롤링 완료: 유천호 강화군수, 내년도 군정 운영방향 시정연설
#  - 2페이지 크롤링 완료: 강화군, 내년 예산안 6612억...유천호 군수 "군민 행복" 강조
#  - 2페이지 크롤링 완료: 유천호 강화군수, 2024년 군정 운영방향 시정연설
#  - 2페이지 크롤링 완료: 종로구, 종로사랑 여성누리단 종합평가보고회 개최
#  - 2페이지 크롤링 완료: 유천호 강화군수, '군민 행복한 일상' 목표 제시
#  - 2페이지 크롤링 완료: 유천호 인천 강화군수, 2024년 군정 운영방향 제시
#  - 2페이지 크롤링 완료: 원주시, 가로등형 방범 블랙박스보안등총 136대 설치 완료
# ...

# %%
# '경찰서 안전' 크롤링 1주차

import requests
from bs4 import BeautifulSoup
from newspaper import Article, ArticleException
import pandas as pd

titles = []
contents = []

for i in range(1, 1690,10):
    link = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EA%B2%BD%EC%B0%B0%EC%84%9C%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=2&ds=2023.11.03&de=2023.12.03&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start=' + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    original_url_elements = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    original_url = original_url_elements[0]['href'] if original_url_elements else None
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']
        
        if original_url:
            news_url = original_url

        try:
            # Attempt to download and parse the article
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

        except ArticleException as e:
            # Handle the exception based on the status code
            print(f" - {i//10 + 1}페이지: {title.get_text(strip=True)} - ArticleException (skipping)")


# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_police_1주차.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: '쇼핑몰 수천억 매출' 여에스더, 식약처 前 과장에 '고발' 당했다…무슨 일?
#  - 1페이지 크롤링 완료: 대구운전면허시험장 외국인 상담 창구 '호응'
#  - 1페이지 크롤링 완료: "허위·과장 광고" 여에스더 고발한 전직 식약처 과장
#  - 1페이지 크롤링 완료: 태양광LED 위치 안내표지판 추가 설치
#  - 1페이지 크롤링 완료: '2023 세종 빛 축제' 민·관 합동안전챙긴다
#  - 1페이지 크롤링 완료: [제16회 진해마라톤대회 건강달리기] 추위야 물렀거라~ 해군 영내서 달림이들...
#  - 1페이지 크롤링 완료: 포항북부경찰서음주운전·교통법규위반 단속 강화
#  - 1페이지 크롤링 완료: 포항북부소방서, 다수사상자 발생대비 구급대응훈련 실시
#  - 1페이지 크롤링 완료: 봉화군, '겨울철 제설종합대책' 추진 총력!
#  - 1페이지 크롤링 완료: 서울 심야 자율주행버스 4일 시동
#  - 2페이지 크롤링 완료: 서울 심야 자율주행버스 4일 시동
#  - 2페이지 크롤링 완료: 경북자치경찰위원회,안전한 경북 경찰공무원 역량강화 교육
#  - 2페이지 크롤링 완료: 상주시, 남산근린공원 공중화장실 안심 비상벨 설치
#  - 2페이지 크롤링 완료: 김천경찰서남부지구대, 오찬 접대 행사 개최
#  - 2페이지 크롤링 완료: 포항해경, 경주지진 발빠른 점검으로 주민불안 해소
#  - 2페이지 크롤링 완료: 문경경찰서, 범죄피해자 주거환경 개선 지원 활동 전개
#  - 2페이지 크롤링 완료: 10대 여학생, 만취한 채 킥보드 타다가…승용차와 '쾅'
#  - 2페이지 크롤링 완료: 청송군, 여성폭력 예방 캠페인 실시
#  - 2페이지 크롤링 완료: 구미시, 여성폭력 추방주간 기념 캠페인
#  - 2페이지 크롤링 완료: 부산 이륜차 교통사고 다발지역 12곳에 후면번호판 무인 교통단속 시스템 구축
#  - 3페이지 크롤링 완료: 부산 오토바이 사고 다발지역 12곳 후면번호판 단속
# ...

# %%
# 경찰서 안전' 크롤링 2주차

import requests
from bs4 import BeautifulSoup
from newspaper import Article, ArticleException
import pandas as pd

titles = []
contents = []

for i in range(1, 1560,10):
    link = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EA%B2%BD%EC%B0%B0%EC%84%9C%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=3&ds=2023.11.19&de=2023.11.25&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231119to20231125,a:all&start=' + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    original_url_elements = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    original_url = original_url_elements[0]['href'] if original_url_elements else None
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']
        
        if original_url:
            news_url = original_url

        try:
            # Attempt to download and parse the article
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

        except ArticleException as e:
            # Handle the exception based on the status code
            print(f" - {i//10 + 1}페이지: {title.get_text(strip=True)} - ArticleException (skipping)")


# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_police_2주차.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 여가부 무턱대고 줄인 예산에 상담소는 ‘막막’ ‘감당 안 된다’
#  - 1페이지 크롤링 완료: "시민 편의 위해 할 수 있는 것 다 한다" … 익산시 · 익산경찰서의 협력 맞...
#  - 1페이지 크롤링 완료: “차이를 차별하지 맙시다” 무지갯빛 행진…창원서 퀴어축제 열려
#  - 1페이지 크롤링 완료: 전주대, 개인형 이동장치안전캠페인 실시
#  - 1페이지 크롤링 완료: 공주시, '안전도시 공주' 만들기 총력
#  - 1페이지 크롤링 완료: 경찰 보호 속안전하게 열린 '경남퀴어문화축제 거리행진'
#  - 1페이지 크롤링 완료: [동정] 윤소식 전 대전경찰청장, 출판기념회 통해 본격 세몰이 나설 예정
#  - 1페이지 크롤링 완료: 의정부 고산지구 제1공영주차장, 범죄예방 우수주차장 인증 획득
#  - 1페이지 크롤링 완료: 공주시, '안전도시 공주' 만들기 총력
#  - 1페이지 크롤링 완료: 양산 국도35호선-석금산택지 연결도로 27일 개통
#  - 2페이지 크롤링 완료: 허위 서류로 '말 안락사 보조금' 횡령···동물보호단체, 엄벌과 말 보호·관...
#  - 2페이지 크롤링 완료: 성남중원경찰서,‘정밀측위 기기’활용, 자살기도자 조기 발견 -
#  - 2페이지 크롤링 완료: 속초시, 전국 최초 디지털 트윈 플랫폼 활용 제설작업 추진
#  - 2페이지 크롤링 완료: 속초해경, 선박 화재 예방안전점검…최근 3년간 15건 발생
#  - 2페이지 크롤링 완료: 한파 녹인 '범죄예방'…경기남부경청·안양시 '안전비전' 맞손
#  - 2페이지 크롤링 완료: "민관경이 범죄 예방 협력"…'안양 시민안전비전' 선포
#  - 2페이지 크롤링 완료: 전남자치경찰위, 이달의 우수 자치경찰 표창
#  - 2페이지 크롤링 완료: 구리시, 2023년 하반기 특이민원 대비 경찰 합동 모의 훈련
#  - 2페이지 크롤링 완료: 구미시, 민·관 협력 강화 … 넥스트 팬데믹 대비한다!
# ...

# %%
# 경찰서 안전' 크롤링 3주차

import requests
from bs4 import BeautifulSoup
from newspaper import Article, ArticleException
import pandas as pd

titles = []
contents = []

for i in range(1, 1770,10):
    link = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EA%B2%BD%EC%B0%B0%EC%84%9C%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=3&ds=2023.11.12&de=2023.11.18&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231112to20231118,a:all&start=' + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    original_url_elements = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    original_url = original_url_elements[0]['href'] if original_url_elements else None
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']
        
        if original_url:
            news_url = original_url

        try:
            # Attempt to download and parse the article
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

        except ArticleException as e:
            # Handle the exception based on the status code
            print(f" - {i//10 + 1}페이지: {title.get_text(strip=True)} - ArticleException (skipping)")


# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_police_3주차.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 단양군, 내년 3월까지 '도로제설 대책기간' 설정
#  - 1페이지 크롤링 완료: 압송 중 피의자 도주…경찰차 안에서 풀어준 수갑이 화근
#  - 1페이지 크롤링 완료: 경기북부경찰, 20일부터 연말연시 음주운전 집중단속
#  - 1페이지 크롤링 완료: 경찰, SPC 샤니 끼임 사고 관련 대표이사 검찰 송치
#  - 1페이지 크롤링 완료: 경찰 "샤니 50대 노동자 끼임 사망사고, 이강섭 대표이사도 송치"
#  - 1페이지 크롤링 완료: 경찰, 성남 샤니공장 근로자 사망 관련 대표이사 송치
#  - 1페이지 크롤링 완료: 당진시, 아동학대 예방의 날 기념행사 개최
#  - 1페이지 크롤링 완료: 경찰, '샤니 끼임 사망' 대표이사 등 7명 송치
#  - 1페이지 크롤링 완료: SPC 샤니 제빵공장 근로자 사망 관련 대표이사 등 7명 송치
#  - 1페이지 크롤링 완료: 서울시여성가족재단, '세이프 서울, 마이 세이프 소울!' 개최
#  - 2페이지 크롤링 완료: 민변 이창민 "윤석열 정부 검찰, 선택적 수사, 선택적 정의…불공정"
#  - 2페이지 크롤링 완료: SPC 계열 샤니 대표, 검찰 송치…업무상 과실치사 혐의
#  - 2페이지 크롤링 완료: 'SPC 샤니 빵공장 직원 사망' 관련 대표이사 등 7명 송치
#  - 2페이지 크롤링 완료: '샤니공장 사망사고'…경찰, 대표이사까지 송치
#  - 2페이지 크롤링 완료: 고성군청소년상담복지센터, ‘미디어 과의존 예방 및 청소년 유해환경 개선 합...
#  - 2페이지 크롤링 완료: 경찰, 샤니공장 근로자 사망사고 대표이사 등 7인 검찰 송치
#  - 2페이지 크롤링 완료: 잠실대교 인근 한강에서 노후화된 조명탄 발견…군 “폭발 위험성 없어”
#  - 2페이지 크롤링 완료: 손기정 탄생 111주년 기념「2023 손기정평화마라톤대회」개최
#  - 2페이지 크롤링 완료: 경찰, SPC 샤니공장 근로자 사망사고 대표이사도 송치
# ...

# %%
# 경찰서 안전' 크롤링 4주차

import requests
from bs4 import BeautifulSoup
from newspaper import Article, ArticleException
import pandas as pd

titles = []
contents = []

for i in range(1, 1480,10):
    link = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EA%B2%BD%EC%B0%B0%EC%84%9C%20%EC%95%88%EC%A0%84&sort=1&photo=0&field=0&pd=3&ds=2023.11.04&de=2023.11.11&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:from20231104to20231111,a:all&start=' + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    original_url_elements = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')
    original_url = original_url_elements[0]['href'] if original_url_elements else None
    
    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']
        
        if original_url:
            news_url = original_url

        try:
            # Attempt to download and parse the article
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")

        except ArticleException as e:
            # Handle the exception based on the status code
            print(f" - {i//10 + 1}페이지: {title.get_text(strip=True)} - ArticleException (skipping)")


# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('news_police_4주차.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 서산시, 보행안전릴레이 캠페인 추진
#  - 1페이지 크롤링 완료: 포항시 골목길 탈바꿈…시민안전안심거리 주민 '호평'
#  - 1페이지 크롤링 완료: '우리 동네가 달라졌어요'…포항시 안심거리 ‘호평’
#  - 1페이지 크롤링 완료: 부산시 자치경찰委, 화명생태공원 산책로 내 방범용 CCTV 22대 설치
#  - 1페이지 크롤링 완료: 트렁크에서 짐 빼던 시민...주차된 자신의 차에 깔려 '사망'
#  - 1페이지 크롤링 완료: 이상근 고성군수, '2023 공룡나라그란폰도'안전사고 예방 현장점검
#  - 1페이지 크롤링 완료: 한성대학교 행정대학원 사회안전학과, 부산해양경찰서방문
#  - 1페이지 크롤링 완료: 한성대학교 행정대학원 사회안전학과, 부산해양경찰서방문
#  - 1페이지 크롤링 완료: 지드래곤, 마약 같은 소리 따윈 집어 치워 오늘 출석은 삐딱하게 [주간 샷샷샷...
#  - 1페이지 크롤링 완료: 성산구 중앙동, 대한민국 범죄예방대상 경찰청장상 수상
#  - 2페이지 크롤링 완료: 합천 황매산 국민여가 캠핑장, 2023년 공공 우수야영장 선정 [합천소식]
#  - 2페이지 크롤링 완료: 이상근 고성군수, 2023 공룡나라그란폰도안전사고 예방 총력 [고성소식]
#  - 2페이지 크롤링 완료: 이상근 고성군수, 2023 공룡나라그란폰도(자전거대회)안전사고 예방을 위한 ...
#  - 2페이지 크롤링 완료: 포항해경, 연안해역 강풍·파도 사고 위험 '주의보' 발령
#  - 2페이지 크롤링 완료: 제천시,"제8회 대한민국 범죄예방대상" 행안부장관 기관표창 수상
#  - 2페이지 크롤링 완료: 안전한 동작 위한 컨트롤타워, 치안협의회 가동
#  - 2페이지 크롤링 완료: [이사람] "본능적으로"… 폭행당한 여학생 구한 김태진 교수
#  - 2페이지 크롤링 완료: [노컷한컷]'김포' 논란 꾸준, '공매도' 효과 반짝…'빈대' 공포 확산
#  - 2페이지 크롤링 완료: 뉴욕주 올 상반기 폭력범죄 줄었다
# ...

# %%
# '경찰서 안전' 데이터 합치기

import pandas as pd

# 파일명 리스트 생성
file_names = ['news_police_1주차.csv', 'news_police_2주차.csv', 'news_police_3주차.csv', 'news_police_4주차.csv']

# 각 CSV 파일을 pandas DataFrame으로 읽어오기
dataframes = [pd.read_csv(file) for file in file_names]

# DataFrame을 합치기
merged_dataframe = pd.concat(dataframes, ignore_index=True)

# 결과를 하나의 CSV 파일로 저장
merged_dataframe.to_csv('news_police.csv', index=False)

# %%
# 비상벨 text 저장

import pandas as pd
import os

# CSV 파일 경로
csv_file_path = r"C:\Users\yeryu\Desktop\빅데프 최최종\Term_Project-1\CarrotMarket\outputData\news_crawling\news_energency_bell.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = '비상벨 text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_emergency_bell_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.

# %%
# 보안등 text 저장

import pandas as pd
import os

# CSV 파일 경로
csv_file_path = r"C:\Users\yeryu\Desktop\빅데프 최최종\Term_Project-1\CarrotMarket\outputData\news_crawling\news_security_light.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = '보안등 text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_emergency_bell_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.

# %%
# 경찰서 text 저장

import pandas as pd
import os

# CSV 파일 경로
csv_file_path = r"C:\Users\yeryu\Desktop\빅데프 최최종\Term_Project-1\CarrotMarket\outputData\news_crawling\news_police.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = '경찰서 text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_emergency_bell_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.
