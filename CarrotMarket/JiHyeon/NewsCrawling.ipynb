# %%
#!pip install newspaper3k
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.7/97.7 kB 7.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 24.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=ee38896236c8280b158c8dfc4cb2701805baad4846dbcade4c9035a69c2cfe58
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# ...
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=2943f477abbc1e2e4b72d62091b3567138a26c2223e2574055cec840e99ffebb
# ...

# %%
#버스 정류장 크롤링
import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd
from newspaper import Config

titles = []
contents = []

# SSL 인증서 검증 해제
config = Config()
config.verify_ssl = False
config.memoize_articles = True
config.request_timeout = 60

for i in range(1, 610, 10):
    link = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EB%B2%84%EC%8A%A4%EC%A0%95%EB%A5%98%EC%9E%A5&sort=1&photo=0&field=0&pd=2&ds=2023.11.04&de=2023.12.04&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start=" + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    url = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')

    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']

        # Extract article content using newspaper library
        try:
            article = Article(news_url, language='ko', config=config)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")
        except Exception as e:
            print(f" - {i//10 + 1}페이지 크롤링 중 오류 발생: {title.get_text(strip=True)} - {str(e)}")

# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('busNews.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 군포시 '현장 누비며 열린 행정'… 올해 12곳 마무리
#  - 1페이지 크롤링 완료: 수원희망글판 겨울편, 마음의 문 열면 겨울도 봄날
#  - 1페이지 크롤링 완료: 거제 아파트 매각예정가 1억 1840만 원
#  - 1페이지 크롤링 중 오류 발생: 김해숙, 20대 시절 미모 엄청나네 “학창 시절 남학생이 보러 나와”(미우새) - Article `download()` failed with HTTPSConnectionPool(host='www.newsen.com', port=443): Max retries exceeded with url: /news_view.php?uid=202312041751580510 (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1007)'))) on URL https://www.newsen.com/news_view.php?uid=202312041751580510
#  - 1페이지 크롤링 완료: "무서워서버스못타겠다"...끊이지 않는 불만 민원
#  - 1페이지 크롤링 완료: [단독] 이삿짐 트럭 몰다버스정류장'쾅'…무면허 몽골인 검거
#  - 1페이지 크롤링 완료: 구로·금천서 ‘연쇄 강도’ 30대 “주식 실패로 돈 필요해서” [영상]
#  - 1페이지 크롤링 완료: "장애인 35만명 구강건강 책임졌죠"
#  - 1페이지 크롤링 완료: 호텔스닷컴, 최상의 스키 여행지 및 국내, 일본, 캐나다, 프랑스 숙박지 공개
#  - 1페이지 크롤링 완료: [가장 보통의 투자] 연말정산 전략은 연초에 세워야 효과적
#  - 2페이지 크롤링 완료: 정기고, ‘썸’ 뒤로하고 겨울빛 ‘her’ 예고...‘힐링 보이스’가 돌아온다
# ...

# %%
#지하철역 크롤링
import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd

titles = []
contents = []

for i in range(1, 610, 10):
    link = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=cctv&sort=1&photo=0&field=0&pd=2&ds=2023.11.04&de=2023.12.04&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start=" + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    url = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')

    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']

        # Extract article content using newspaper library
        try:
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")
        except Exception as e:
            print(f" - {i//10 + 1}페이지 크롤링 중 오류 발생: {title.get_text(strip=True)} - {str(e)}")

# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('subwayNews.csv', index=False)
# Out:
#  - 1페이지 크롤링 완료: 지역의원 특별교부세 확보 잇따라
#  - 1페이지 크롤링 완료: '우아한 제국' 한지완, 손성윤과 손잡고 이시강 복수→정체 발각 위기 [종합]
#  - 1페이지 크롤링 완료: '우아한 제국' 금고 뒤지는 이시강, 침입 흔적에 한지완 의심할까...김미라X권...
#  - 1페이지 크롤링 완료: 박병석 의원, 행안부 특별교부세 8억 확보
#  - 1페이지 크롤링 완료: 나라 망신시키는 바가지 상혼
#  - 1페이지 크롤링 완료: 서대문구, '여성안심 귀가 야간 합동 순찰' 강화
#  - 1페이지 크롤링 완료: 이종배 의원, 충주시 행정안전부 특별교부세 31억 ‘확보’
#  - 1페이지 크롤링 완료: 부산 곳곳에 골칫거리 ‘무법 오토바이’ 감시할 AI ‘눈’ 설치
#  - 1페이지 크롤링 완료: [IPA 소식] ‘2023년 IoT 테스트필드 구축과제’ 구축 완료外
#  - 1페이지 크롤링 완료: '우아한 제국' 이시강, 서재 비밀 금고 위기…"침입자 있다"
#  - 2페이지 크롤링 완료: 정진석 의원, 행안부 특별교부세 87억 ‘확보’…역대 ‘최고액’
#  - 2페이지 크롤링 완료: 박형수 의원, 행안부 하반기 특교세 26건 107억 확보
#  - 2페이지 크롤링 완료: [CEO 인터뷰]이한상 유니버스AI 대표, 안면인식 결제 시대…아시아 시장 통합...
#  - 2페이지 크롤링 완료: 화섬식품노조 "라이온켐텍 직장폐쇄 당장 철회" 촉구
#  - 2페이지 크롤링 완료: 때렸지만 폭행 아니라더니…학폭 피해자 처벌에 2년 반 걸려
#  - 2페이지 크롤링 완료: “골든타임 잡아라” 전국 첫 응급의료상황실
#  - 2페이지 크롤링 완료: 강남구, 가족배려주차구획으로 여성우선주차구획 904면 전환
#  - 2페이지 크롤링 완료: 경인지역 의원들, 지역사업위한 국비 확보
#  - 2페이지 크롤링 완료: 군포시 '현장 누비며 열린 행정'… 올해 12곳 마무리
# ...

# %%
# 'CCTV' 크롤링
import requests
from bs4 import BeautifulSoup
from newspaper import Article
import pandas as pd

titles = []
contents = []

for i in range(1, 610, 10):
    link = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=cctv&sort=1&photo=0&field=0&pd=2&ds=2023.11.04&de=2023.12.04&mynews=0&office_type=0&office_section_code=0&news_office_checked=&office_category=0&service_area=0&nso=so:dd,p:1m,a:all&start=" + str(i)
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'html.parser')
    url = soup.select('#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans > div.media_end_head_info_datestamp > a')

    # Extract news titles and links
    news_titles = soup.find_all('a', class_='news_tit')
    for title in news_titles:
        news_url = title['href']

        # Extract article content using newspaper library
        try:
            article = Article(news_url, language='ko', fetch_images=False, request_timeout=20)
            article.download()
            article.parse()

            # Append data to lists
            titles.append(title.get_text(strip=True))
            contents.append(article.text)

            print(f" - {i//10 + 1}페이지 크롤링 완료: {title.get_text(strip=True)}")
        except Exception as e:
            print(f" - {i//10 + 1}페이지 크롤링 중 오류 발생: {title.get_text(strip=True)} - {str(e)}")

# Create a DataFrame
data = {'제목': titles, '기사 내용': contents}
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('cctvNews.csv', index=False)

# %%
# 버스정류장 text 저장
import pandas as pd
import os

# CSV 파일 경로
csv_file_path = "D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/JiHyeon/busNews.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = 'D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/outputData/news_crawling/버스정류장 text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_bus_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.

# %%
# 지하철역 text 저장
import pandas as pd
import os

# CSV 파일 경로
csv_file_path = "D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/JiHyeon/subwayNews.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = 'D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/outputData/news_crawling/지하철역 text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_subway_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.

# %%
# cctv text 저장
import pandas as pd
import os

# CSV 파일 경로
csv_file_path = "D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/JiHyeon/cctvNews.csv"

# CSV 파일 읽기
df = pd.read_csv(csv_file_path)

# 본문을 텍스트 파일로 저장할 디렉토리 생성
output_dir = 'D:/바탕화면/대학수업/3-2/빅데프/팀플/Term_Project/CarrotMarket/outputData/news_crawling/cctv text'
os.makedirs(output_dir, exist_ok=True)

# 각 행의 본문을 텍스트 파일로 저장
for index, row in df.iterrows():
    # 파일명 생성 (예: article_1.txt, article_2.txt, ...)
    output_file_path = os.path.join(output_dir, f'news_cctv_{index + 1}.txt')

    # 본문 값을 파일에 쓰기
    with open(output_file_path, 'w', encoding='utf-8') as file:
        file.write(str(row['기사 내용']))  # '본문'은 실제 CSV 파일의 본문 컬럼명에 따라 수정

print("텍스트 파일로 저장이 완료되었습니다.")
# Out:
# 텍스트 파일로 저장이 완료되었습니다.
